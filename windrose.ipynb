# %%
import windrose as windroseAxes
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Out:
# C:\Users\Awuni Jeremiah\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.0' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\Awuni Jeremiah\Anaconda3\lib\site-packages\pandas\core\arrays\masked.py:62: UserWarning: Pandas requires version '1.3.4' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
Jerry=pd.read_csv('windrose data.csv')
Jerry
# Out:
#      YEAR  MO  DY  WS10M  WD10M
# 0    2023   1   1   4.04  55.50
# 1    2023   1   2   4.09  47.44
# 2    2023   1   3   4.41  48.38
# 3    2023   1   4   4.04  47.94
# 4    2023   1   5   4.09  64.94
# ..    ...  ..  ..    ...    ...
# 360  2023  12  27   4.44  48.69
# 361  2023  12  28   4.46  48.38
# 362  2023  12  29   4.46  46.25
# 363  2023  12  30   4.20  48.19
# 364  2023  12  31   3.71  51.50
#
# [365 rows x 5 columns]

# %%
ws=Jerry['WS10M']
ws
# Out:
# 0      4.04
# 1      4.09
# 2      4.41
# 3      4.04
# 4      4.09
#        ...
# 360    4.44
# 361    4.46
# 362    4.46
# 363    4.20
# 364    3.71
# Name: WS10M, Length: 365, dtype: float64

# %%
wd=Jerry['WD10M']
wd
# Out:
# 0      55.50
# 1      47.44
# 2      48.38
# 3      47.94
# 4      64.94
#        ...
# 360    48.69
# 361    48.38
# 362    46.25
# 363    48.19
# 364    51.50
# Name: WD10M, Length: 365, dtype: float64

# %%
from windrose import WindroseAxes

ax = WindroseAxes.from_ax()
ax.bar(wd,ws, normed=True, opening=0.9, edgecolor="white", cmap=plt.get_cmap('jet'),bins=np.arange(0.01, 8, 1))
ax.set_legend(title='wind speed(m/s)',fontsize=10, loc='upper right',bbox_to_anchor=(1.20,0.9))
ax.tick_params(axis='both', which='major',labelsize=10)
ax.set_title('WINDROSE FOR TONGO,TALENSI,UPPER EAST,GHA')
# Out:
# Text(0.5, 1.0, 'WINDROSE FOR TONGO,TALENSI,UPPER EAST,GHA')
